# %%
from model import *
from viz import *
# %matplotlib inline
plt.rcParams['figure.figsize'] = [12.0, 9.0]

# %%
data = get_data()

# %%
plot_map(*data(1, 5))

# %%
plot_map(*data(1, 8))

# %%
plot_map(*data(1, 14))
